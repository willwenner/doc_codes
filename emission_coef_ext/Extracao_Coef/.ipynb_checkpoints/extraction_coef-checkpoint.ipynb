# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re 

from cherab.openadas import OpenADAS, parse
from cherab.core.atomic import carbon

# %%
adas = OpenADAS(permit_extrapolation=True)

# %%
def new_spectroscopyline_identifier(line):
    # Checando se linha tem header
    return '/TYPE' in line and "A" in line

def creating_table_of_Pecs(datas):
    #Matriz por comprimento de onda
    matrix_per_wl = []
    #Iterar linhas checando por linhas novas
    
    idx = 0
    
    while idx < len(datas):
        
        row = datas[idx]
        
        if new_spectroscopyline_identifier(row):
            match = re.search(r"(\d+\.?\d*)A",row)
            wavelength = match.group(0)
            if match:
                match_type = re.search(r"/TYPE\s*=\s*(\w+)",row)
                idx += 7

                values = []

                for _ in range(int(3*24)):
                    if idx < len(datas):
                        row_data = datas[idx]
                        
                        # Converte os 8 elementos da linha para float
                        for num in row_data.split():
                            values.append(float(num))

                        idx += 1
                matrix_pec = np.array(values).reshape(24,21)         
                
                

        wavelength_matrix = {
                "Wavelength": wavelength,
                "Type": match_type,
                "matrix_pec": matrix_pec
        }
            
            
        matrix_per_wl.append(wavelength_matrix)    
        idx +=1
                
    return matrix_per_wl


def read_archive(path):
    if type(path) != str:
       return print("Please inform a valid path")
    
    with open(path,'r') as archive:
        lines = [row.strip() for row in archive]
        lines.pop(0)            
    return lines

# %%
a = read_archive("pecs96.dat")

# %%
lista_pecs = creating_table_of_Pecs(a)

# %%
lista_pecs[0]["matrix_pec"][7,8]
# Out:
# 1.11e-11
